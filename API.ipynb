# %% [markdown]
# we are using pycoingecko snd api is coingeckoAPI
# which is a crypto currency data
# and as crypto currency gets updated time tot imt its very suitable for us

# %%
pip install pycoingecko
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pycoingecko import CoinGeckoAPI

# %%
cg=CoinGeckoAPI()
cg

# %%
bitcoin_data=cg.get_coin_market_chart_by_id(id='bitcoin',vs_currency='usd',days=30)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# c:\users\harsh\appdata\local\programs\python\python39\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# c:\users\harsh\appdata\local\programs\python\python39\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# c:\users\harsh\appdata\local\programs\python\python39\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     952     addrlist = []
# ...

# %%
bitcoin_data.keys()
# Out:
# dict_keys(['prices', 'market_caps', 'total_volumes'])

# %%
bitcoin_data['prices']
# Out:
# [[1622970458998, 36356.78099088036],
#  [1622974194078, 36171.82444354311],
#  [1622977320276, 36011.613974451524],
#  [1622981064213, 35941.81753146294],
#  [1622984918004, 35907.93720604346],
#  [1622988229172, 35673.23835851259],
#  [1622991861269, 36166.70622013614],
#  [1622995388795, 36182.16101334534],
#  [1622999000406, 36236.62504054426],
#  [1623003171116, 36007.430432499124],
#  [1623006754382, 35852.89329760041],
#  [1623009770608, 35751.353728901304],
#  [1623013411080, 35933.0700048548],
#  [1623017508590, 35927.2869345765],
#  [1623020618262, 35502.10823448369],
#  [1623024134276, 35834.4744744042],
#  [1623028333494, 36326.57449502619],
#  [1623032177611, 36740.145420534325],
#  [1623035284354, 36750.90365081315],
#  [1623039193524, 36654.01540186706],
#  [1623042235076, 36356.034055962766],
#  [1623046369417, 36277.42533250393],
#  [1623049946894, 36110.8681903359],
#  [1623053088622, 36216.415125741165],
#  [1623056542163, 36204.59083860269],
# ...

# %%
import pandas as pd

data=pd.DataFrame(bitcoin_data,columns=['Timestamp','Price'])
data['Date']=pd.to_datetime(data['Timestamp'],unit='ms')

# %%
data
# Out:
# Empty DataFrame
# Columns: [Timestamp, Price, Date]
# Index: []

# %%
candlestick_data=data.groupby(data.Date.dt.date).agg({'Price':['min','max','first','last']})

# %%
candlestick_data
# Out:
# Empty DataFrame
# Columns: [(Price, min), (Price, max), (Price, first), (Price, last)]
# Index: []

# %%
bitcoin_price_data=cg.get_price(ids=)
bitcoin_price_data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-5267e85f4fb6> in <module>
# ----> 1 bitcoin_price_data=cg.get_price()
#       2 bitcoin_price_data
#
# c:\users\harsh\appdata\local\programs\python\python39\lib\site-packages\pycoingecko\utils.py in input_args(*args, **kwargs)
#      10         args = [arg_preprocessing(v) for v in args]
#      11
# ---> 12         return func(*args, **kwargs)
#      13
#      14     return input_args
#
# TypeError: get_price() missing 2 required positional arguments: 'ids' and 'vs_currencies'
